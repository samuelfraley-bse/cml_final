# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 100)
plt.style.use("default")

# %% [markdown]
# Load HEF data for classification taks

# %%
# === HEF / classification data ===
train_clf = pd.read_csv("C:\Users\sffra\Downloads\BSE 2025-2026\cml_final\data\raw\MIMIC III dataset HEF\mimic_train_HEF.csv")  # adjust path
test_clf  = pd.read_csv("C:\Users\sffra\Downloads\CML_final_project_2025\MIMIC III dataset HEF\mimic_test_HEF.csv")   # optional here

train_clf.head()
